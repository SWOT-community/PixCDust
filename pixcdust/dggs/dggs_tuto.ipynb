# %%
import pixcdust
from pixcdust.readers import PixCNcSimpleReader
import xarray as xr

# %%
path = "/tmp/pixc/SWOT_L2_HR_PIXC_011_148_098R_20240220T032331_20240220T032342_PIC0_01.nc"
reader = PixCNcSimpleReader(path)
reader.read()
reader.data.data_vars
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/swot_pixc_study/pixc-env/lib/python3.10/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/Documents/swot_pixc_study/pixc-env/lib/python3.10/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/tmp/pixc/SWOT_L2_HR_PIXC_011_148_098R_20240220T032331_20240220T032342_PIC0_01.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '37eba0ce-a753-4e99-be5f-715998204276']
#
# ...

# %%
reader.data['height']
# Out:
# <xarray.DataArray 'height' (points: 4847840)> Size: 19MB
# [4847840 values with dtype=float32]
# Coordinates:
#     latitude   (points) float64 39MB 44.33 44.33 44.33 ... 43.91 43.91 43.91
#     longitude  (points) float64 39MB 0.5563 0.5569 0.5573 ... 1.514 1.513 1.514
#   * points     (points) object 39MB POINT (0.5563121811318297 44.328366398209...
# Indexes:
#     points   GeometryIndex (crs=EPSG:4326)
# Attributes:
#     long_name:     height above reference ellipsoid
#     units:         m
#     quality_flag:  geolocation_qual
#     valid_min:     -1500.0
#     valid_max:     15000.0
#     comment:       Height of the pixel above the reference ellipsoid.

# %%
ds_h3 = reader.to_h3(variables = 'height', resolution = 8)
ds_h3
# Out:
# <xarray.Dataset> Size: 295kB
# Dimensions:   (cell_ids: 9219)
# Coordinates:
#   * cell_ids  (cell_ids) int64 74kB 613499208944582655 ... 613498942656610303
#     h3_lon    (cell_ids) float64 74kB 0.6636 1.476 0.9777 ... 0.727 1.01 1.186
#     h3_lat    (cell_ids) float64 74kB 44.05 43.92 44.42 ... 44.45 44.35 43.96
# Data variables:
#     height    (cell_ids) float64 74kB 156.4 197.1 nan 136.6 ... nan 279.7 132.9
# Indexes:
#     cell_ids  H3Index(level=8)
# Attributes:
#     description:                 cloud of geolocated interferogram pixels
#     interferogram_size_azimuth:  3243
#     interferogram_size_range:    4664
#     looks_to_efflooks:           1.5334246881326674
#     num_azimuth_looks:           7.0
#     azimuth_offset:              9

# %%
ds_h3['height'].dggs.explore()
# Out:
# Map(custom_attribution='', layers=(SolidPolygonLayer(filled=True, get_fill_color=arro3.core.ChunkedArray<Fixed…

# %%
ds_healpix =reader.to_healpix(variables = 'height', resolution = 12)

# %%
ds_healpix['height'].dggs.explore()
# Out:
# Map(custom_attribution='', layers=(SolidPolygonLayer(filled=True, get_fill_color=arro3.core.ChunkedArray<Fixed…
