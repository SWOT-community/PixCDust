# %%
from pixcdust.tests.mock import mock_netcdf_xarray

# %%
data = mock_netcdf_xarray()
data
# Out:
# <xarray.Dataset> Size: 500kB
# Dimensions:         (points: 10000, longitude: 10000, latitude: 10000)
# Coordinates:
#   * longitude       (longitude) float64 80kB 10.0 10.0 10.0 ... 20.0 20.0 20.0
#   * latitude        (latitude) float64 80kB 40.0 40.0 40.0 ... 50.0 50.0 50.0
# Dimensions without coordinates: points
# Data variables:
#     height          (points) float64 80kB 0.7477 0.6375 ... -0.1959 -0.2778
#     sig0            (points) float64 80kB 73.12 4.192 8.215 ... 4.356 32.88
#     classification  (points) float32 40kB 2.0 5.0 3.0 2.0 ... 1.0 6.0 3.0 0.0
#     tile_number     (points) uint16 20kB 17 17 17 17 17 17 ... 17 17 17 17 17 17
#     cycle_number    (points) uint16 20kB 238 238 238 238 238 ... 238 238 238 238
#     pass_number     (points) uint16 20kB 23 23 23 23 23 23 ... 23 23 23 23 23 23
#     time            (points) datetime64[ns] 80kB 2024-06-05T11:40:12 ... 2024...

# %%
from datetime import datetime
import numpy as np

# %%
# %time
a = np.ones(100000).astype(datetime)
a[:] = datetime(2023,1,1)
a
# Out:
# CPU times: user 1e+03 ns, sys: 1 μs, total: 2 μs
# Wall time: 2.86 μs
# array([datetime.datetime(2023, 1, 1, 0, 0),
#        datetime.datetime(2023, 1, 1, 0, 0),
#        datetime.datetime(2023, 1, 1, 0, 0), ...,
#        datetime.datetime(2023, 1, 1, 0, 0),
#        datetime.datetime(2023, 1, 1, 0, 0),
#        datetime.datetime(2023, 1, 1, 0, 0)], dtype=object)

# %%
# %time
np.array([datetime(2024, 6, 5, 11, 40, 12) for _ in range(100000)])
# Out:
# CPU times: user 3 μs, sys: 1 μs, total: 4 μs
# Wall time: 8.11 μs
# array([datetime.datetime(2024, 6, 5, 11, 40, 12),
#        datetime.datetime(2024, 6, 5, 11, 40, 12),
#        datetime.datetime(2024, 6, 5, 11, 40, 12), ...,
#        datetime.datetime(2024, 6, 5, 11, 40, 12),
#        datetime.datetime(2024, 6, 5, 11, 40, 12),
#        datetime.datetime(2024, 6, 5, 11, 40, 12)], dtype=object)
