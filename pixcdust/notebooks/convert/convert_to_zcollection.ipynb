# %%
from pixcdust.converters.zarr import Nc2ZarrConverter
from glob import glob

# %% [markdown]
# # Create a zarr database

# %%
pixc = Nc2ZarrConverter(
            sorted(glob('/tmp/pixc'+'/*/*nc')),
            "/tmp/pixc_zarr",
            variables=['height', 'sig0', 'classification'],
            mode='o',
        )
pixc.database_from_nc()
# Out:
# /home/vschaffn/Documents/swot_pixc_study/pixc-env/lib/python3.10/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 46275 instead
#   warnings.warn(
# 2024-12-09 16:47:16,176 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42047' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-e765e98d2d76bccc211863118be15faf', 17), ('concatenate-e765e98d2d76bccc211863118be15faf', 24), ('concatenate-e765e98d2d76bccc211863118be15faf', 21)} (stimulus_id='handle-worker-cleanup-1733759236.17648')
# 2024-12-09 16:47:16,182 - distributed.nanny - WARNING - Restarting worker
# 2024-12-09 16:47:17,311 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:41699' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-e765e98d2d76bccc211863118be15faf', 22), ('concatenate-e765e98d2d76bccc211863118be15faf', 7), ('concatenate-e765e98d2d76bccc211863118be15faf', 19), 'original-open_dataset-longitude-2326064dc2d9dba46377396b0f4e0baf'} (stimulus_id='handle-worker-cleanup-1733759237.311619')
# 2024-12-09 16:47:17,321 - distributed.scheduler - ERROR - Couldn't gather keys: {('concatenate-e765e98d2d76bccc211863118be15faf', 21): 'waiting', ('concatenate-e765e98d2d76bccc211863118be15faf', 24): 'memory', ('concatenate-e765e98d2d76bccc211863118be15faf', 17): 'memory', ('concatenate-e765e98d2d76bccc211863118be15faf', 7): 'waiting', ('concatenate-e765e98d2d76bccc211863118be15faf', 19): 'waiting', ('concatenate-e765e98d2d76bccc211863118be15faf', 22): 'waiting'}
# 2024-12-09 16:47:17,326 - distributed.client - WARNING - Couldn't gather 6 keys, rescheduling (('concatenate-e765e98d2d76bccc211863118be15faf', 21), ('concatenate-e765e98d2d76bccc211863118be15faf', 24), ('concatenate-e765e98d2d76bccc211863118be15faf', 17), ('concatenate-e765e98d2d76bccc211863118be15faf', 7), ('concatenate-e765e98d2d76bccc211863118be15faf', 19), ('concatenate-e765e98d2d76bccc211863118be15faf', 22))
# 2024-12-09 16:47:17,333 - distributed.nanny - WARNING - Restarting worker
# Exception ignored in: <function CachingFileManager.__del__ at 0x7b2748e08310>
# Traceback (most recent call last):
#   File "/home/vschaffn/Documents/swot_pixc_study/pixc-env/lib/python3.10/site-packages/xarray/backends/file_manager.py", line 250, in __del__
#     self.close(needs_lock=False)
#   File "/home/vschaffn/Documents/swot_pixc_study/pixc-env/lib/python3.10/site-packages/xarray/backends/file_manager.py", line 234, in close
#     file.close()
#   File "src/netCDF4/_netCDF4.pyx", line 2669, in netCDF4._netCDF4.Dataset.close
#   File "src/netCDF4/_netCDF4.pyx", line 2636, in netCDF4._netCDF4.Dataset._close
#   File "src/netCDF4/_netCDF4.pyx", line 2164, in netCDF4._netCDF4._ensure_nc_success
# RuntimeError: NetCDF: HDF error
# double free or corruption (out)
# 2024-12-09 16:47:18,886 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37301' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-1ea7f0f35f270ba1cf9461ed0a7120ee', 18), 'original-open_dataset-latitude-79185eb029d205824400ce97aa6923d6', ('concatenate-1ea7f0f35f270ba1cf9461ed0a7120ee', 21)} (stimulus_id='handle-worker-cleanup-1733759238.886627')
# 2024-12-09 16:47:18,894 - distributed.nanny - WARNING - Restarting worker
# 2024-12-09 16:47:20,190 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39715' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('open_dataset-latitude-concatenate-1ea7f0f35f270ba1cf9461ed0a7120ee', 21)} (stimulus_id='handle-worker-cleanup-1733759240.1901243')
# 2024-12-09 16:47:20,194 - distributed.nanny - WARNING - Restarting worker
# /home/vschaffn/Documents/swot_pixc_study/pixc-env/lib/python3.10/site-packages/distributed/client.py:3361: UserWarning: Sending large graph of size 95.66 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(

# %% [markdown]
# # Read a zarr database

# %%
from pixcdust.readers.zarr import ZarrReader
import datetime

# %%
pixcr = ZarrReader("/tmp/pixc_zarr")
pixcr.read((datetime.datetime(2024,8,3), datetime.datetime(2024,8,12)))
pixc
# Out:
# /home/vschaffn/Documents/swot_pixc_study/pixc-env/lib/python3.10/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 38239 instead
#   warnings.warn(

# %%
gdf_pixc = pixcr.to_geodataframe()
gdf_pixc
# Out:
# /home/vschaffn/Documents/swot_pixc_study/pixcdust/converters/geo_utils.py:19: UserWarning: No active geometry column to be set. The resulting object will be a pandas.DataFrame with geopandas.GeometryArray(s) containing geometry and CRS information. Use `.set_geometry()` to set an active geometry and upcast to the geopandas.GeoDataFrame manually.
#   return ds.xvec.to_geodataframe(*args, **kwargs)
#              height                time       sig0      geoid  pass_number  \
# points
# 0        361.253418 2024-08-03 19:45:40   0.411282  51.182461          113
# 1        361.125977 2024-08-03 19:45:40  -2.102726  51.175888          113
# 2        361.501373 2024-08-03 19:45:40  -0.589899  51.166866          113
# 3        331.433807 2024-08-03 19:45:40   1.692791  51.193218          113
# 4        330.694336 2024-08-03 19:45:40   2.817688  51.192886          113
# ...             ...                 ...        ...        ...          ...
# 8504480   45.035694 2024-08-03 19:45:40  17.946924  48.903179          113
# 8504481   44.146286 2024-08-03 19:45:40  28.999247  48.903172          113
# 8504482   43.519547 2024-08-03 19:45:40  41.731537  48.903179          113
# 8504483   43.197521 2024-08-03 19:45:40  28.085815  48.903198          113
# 8504484   46.079216 2024-08-03 19:45:40  10.793365  48.903370          113
#
#          cycle_number  tile_number  longitude  classification   latitude
# points
# 0                  19          231  -1.039658             1.0  43.213745
# 1                  19          231  -1.044424             1.0  43.214625
# 2                  19          231  -1.050687             1.0  43.215780
# 3                  19          231  -1.031372             1.0  43.212216
# 4                  19          231  -1.031639             1.0  43.212265
# ...               ...          ...        ...             ...        ...
# 8504480            19          231  -1.633629             4.0  43.915054
# 8504481            19          231  -1.633610             4.0  43.915051
# 8504482            19          231  -1.633628             4.0  43.915054
# 8504483            19          231  -1.633689             4.0  43.915065
# 8504484            19          231  -1.634210             7.0  43.915157
#
# [8504485 rows x 10 columns]
